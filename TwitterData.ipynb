# %%
import tweepy, json
import pandas as pd

# %%
# auth = tweepy.OAuthHandler('uBdYOH9ZNIZ3nzjOffdOoPzk4', 'UKDo1Z9Aa9IYUrxAnFEAqruNlzJnKJ6FEaPAwDnbx8h4EDuwOw')
# auth.set_access_token('1463605105840820225-Wmnk5ZqMOvygaPW2IiuMRbtOY0nFfA', 'HwlczAGv8yy7eVAYcMxcgaasZDEGelL7IA59nsYYML241')
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAB6ZWAEAAAAAfJvmx9F6G0MDnmhLDJArok%2Be8DQ%3DVUcIjorrsQQa2PLuwLgs7q81znlHId0DqfwxmlCuEHNflfjZFe')
query = 'COVID, MASKS, VACCINE'
#tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at', 'geo'], place_fields=['country_code', 'geo'], expansions='geo.place_id', max_results=100)

# %%
tweets = []
for response in tweepy.Paginator(client.search_recent_tweets, 
                                 query = 'COVID, MASKS, VACCINE',
                                 user_fields = ['username', 'public_metrics', 'description', 'location'],
                                 tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
                                 place_fields = ['country_code'],
                                 expansions = 'author_id',
                                 #start_time = '2021-12-11T00:00:00Z',
                                 #end_time = '2021-12-16T00:00:00Z',
                              max_results=100):
    tweets.append(response)

# %%
tweets[0].includes['users'][3]
# Out:
# <User id=1459285370835771403 name=Paulina1007 username=Paulina100722>

# %%
tweets[0].includes['users'][3]
# Out:
# <User id=1459285370835771403 name=Paulina1007 username=Paulina100722>

# %%
result = []
user_dict = {}
# Loop through each response object
for response in tweets:
    # Take all of the users, and put them into a dictionary of dictionaries with the info we want to keep
    for user in response.includes['users']:
        user_dict[user.id] = {'username': user.username, 
                              'followers': user.public_metrics['followers_count'],
                              'tweets': user.public_metrics['tweet_count'],
                              'description': user.description,
                              'location': user.location
                             }
    for tweet in response.data:
        # For each tweet, find the author's information
        author_info = user_dict[tweet.author_id]
        # Put all of the information we want to keep in a single dictionary for each tweet
        result.append({'author_id': tweet.author_id, 
                       'username': author_info['username'],
                       'author_description': author_info['description'],
                       'author_location': author_info['location'],
                       'text': tweet.text,
                       'created_at': tweet.created_at,
                       'retweets': tweet.public_metrics['retweet_count'],
                       'replies': tweet.public_metrics['reply_count'],
                       'quote_count': tweet.public_metrics['quote_count']
                      })

# Change this list of dictionaries into a dataframe
df = pd.DataFrame(result)

# %%
result
# Out:
# [{'author_id': 1053785240,
#   'username': 'shimtunley',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @RGHIHygiene4All: Despite the new variant, the WHO continues to advise against travel restrictions, but warns that the (hygiene) measure…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 19, 15, tzinfo=datetime.timezone.utc),
#   'retweets': 309,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 103509670,
#   'username': 'indiraeng',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 18, 22, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 984452302579912704,
#   'username': 'harte_the',
#   'author_description': 'Just a Freedom Loving American',
#   'author_location': 'United States',
#   'text': '@mohr_glen @Jenifer20238204 @impjr @dbongino Show me the science that says the vaccine stops the spread/contraction of Covid-19, or better yet show me the science that proves masks work. Go!',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 17, 2, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1459285370835771403,
#   'username': 'Paulina100722',
#   'author_description': 'President DJT🇺🇸👍🏼❤️ #MAGA #KAG #LEADRIGHT   #STOPTHESTEAL',
#   'author_location': 'Maine, USA',
#   'text': 'RT @CJ_J777: @OregonGovBrown If a vaccinated person gets Covid and spreads Covid how does the vaccine end the pandemic? Scientists say the…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 16, 19, tzinfo=datetime.timezone.utc),
#   'retweets': 4,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 944865799369515008,
#   'username': 'JustinM79380965',
#   'author_description': '',
#   'author_location': 'out there, somewhere',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 16, 19, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1659999492,
#   'username': 'Christina1494',
#   'author_description': 'Freedom of Thought. Just Individualism💜 Spiritually superior ✨ Exercising my Civil Rights ✌️',
#   'author_location': 'Austria',
#   'text': '@AnnMorse11 @ThiemDomi Don\'t lie! \nVaccine do not protect "like an admor" . Vaccinated need carantine, masks, pcr tests etc,  with a reason.\n\nAnd what is the scare of getting Covid ?\nBetter prepare yourself bcs we will all get it - and 99,90% will come out alive and fully healthy.',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 15, 33, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 52814136,
#   'username': 'SiccoVanHoegee',
#   'author_description': '',
#   'author_location': 'Rotterdam',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 15, 17, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1297811891977367552,
#   'username': 'AnnieAdeIe1',
#   'author_description': '🌺Wife Mom Gma Working to Make🇺🇸Great Safe Respected again🌺 \n#BlackLivesMatter\n#Liberal \n#Civility\n#Compassion \n#AntiFa \n#DACA\n#BuildBackBetter #LockTrumpUp',
#   'author_location': '💐Hope & Dreams💐',
#   'text': 'RT @thesheenrocks: @SuspendThis73 @OrwellianCylon @AnnieAdeIe1 @izmks16 @ThePoorMan95 @poopantsbiden @McMehHey_ @4_joc1 @Zer0Access @Snowfl…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 14, 5, tzinfo=datetime.timezone.utc),
#   'retweets': 1,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1249739746441601024,
#   'username': 'purplediscomove',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @StoneColdPillar: @DrTomFrieden It’s not okay to let COVID rage through kids unchecked.\n\nIt’s not okay to send kids to schools without 3…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 13, 51, tzinfo=datetime.timezone.utc),
#   'retweets': 1,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1462508714653593606,
#   'username': 'thesheenrocks',
#   'author_description': 'MAGA is DUMB.',
#   'author_location': None,
#   'text': "@SuspendThis73 @OrwellianCylon @AnnieAdeIe1 @izmks16 @ThePoorMan95 @poopantsbiden @McMehHey_ @4_joc1 @Zer0Access @SnowflakeGQP @jerbear714 @wallington_joe @ThereseOSulliv2 @dogsdontliket @MikeBetts43 @Godslightangel7 @CovieBitch @Q__talk @NikkiStokely89 @chi7510 @66michaelr @MTStringer1 @LindaRosenbaum2 @S__Monkie42 @woodman4tb @chrisg409ubc @Klee34036780 @DV652 @Troy_G65 @Vanessa76_1 @Anti_MagatCult @tallnblonde1 @EricSpahn3 @MoIIySmall @jasonhuynh @najjar_richard @IFitz3 @Glassman1148 @Annie20554592 @1Quetzalcoatl1 @Nguyen_anime3 @BeckLuvsBunnies @Sarah20hays @IMFletcherLives @ghost321 @TJ2020landslide @EricSpahn2 @Gangstakittyboo @waywardmegan15 @MarshallW73 Because stupid MAGA refuses the vaccine and won't wear masks. And now trump idiots are dying fast. https://t.co/v9EBYAzkX1",
#   'created_at': datetime.datetime(2021, 12, 19, 21, 11, 22, tzinfo=datetime.timezone.utc),
#   'retweets': 1,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 21585856,
#   'username': 'sallydibben',
#   'author_description': 'LOVE dogs, travel, fresh air. HATE Tv, extremism, cruelty to animals, overheating.',
#   'author_location': 'Italy',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 11, 22, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1905706459,
#   'username': 'alfie_alf',
#   'author_description': 'U.S. Army - no followers please.... no better place to live then the United States of America. Fight to maintain our freedoms!',
#   'author_location': 'United States',
#   'text': '@RichardGrenell It’s not Trumps fault that people died from Covid. It’s not Biden’s fault that people died from Covid. The virus will do what viruses do. Masks don’t work. The vaccine doesn’t work. Keep the country open and stop with the masks on our children.',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 8, 56, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1099802447973773312,
#   'username': 'friendojustice',
#   'author_description': '@ the x of politics, 🏳️\u200d🌈 rights, & pop culture. Taking down bad takes and aggregating the best of twitter. RTs 🚫 not endorsements. #cancelstudentdebt!',
#   'author_location': None,
#   'text': "RT @thrasherxy: @fred_guttenberg It is Dems who've\n\n—Ended testing sites in NY &amp; SF\n\n—SCOFFED at free home tests \n\n—FAILED to send out mask…",
#   'created_at': datetime.datetime(2021, 12, 19, 21, 8, 47, tzinfo=datetime.timezone.utc),
#   'retweets': 1,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 996562972632866816,
#   'username': 'InnissPetersen',
#   'author_description': 'Harnessing the awesome power of femininity, ethics and authentic relationships in business. Life Long Learner. Lover of deep conversations and red wine.',
#   'author_location': 'Sarnia, Ontario',
#   'text': "RT @DrEliDavid: We have vaccines, and we have vaccine-evading mutations. So what's the endgame for Covid? 🏁\n\nPerpetual lockdowns, travel ba…",
#   'created_at': datetime.datetime(2021, 12, 19, 21, 6, 44, tzinfo=datetime.timezone.utc),
#   'retweets': 601,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 346244121,
#   'username': 'scaelsa',
#   'author_description': 'Mushroom friends: I apologize about  the UFO stuff. UFO friends: I apologize for the mushroom stuff. Truth: I apologize for none of it. I’m a complicated person',
#   'author_location': 'Over the Garden Wall',
#   'text': "RT @mjelse: @fearnley_k I have Long Covid, too, 12 months and 10 days. I do count them. The warning to everyone, from me, is: you don't wan…",
#   'created_at': datetime.datetime(2021, 12, 19, 21, 6, 31, tzinfo=datetime.timezone.utc),
#   'retweets': 97,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 2171847373,
#   'username': 'markhinks06',
#   'author_description': 'Carbon neutral transport. ..cheap as chips, runs on chips',
#   'author_location': 'west mids, worcester England',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 6, 16, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1049079325,
#   'username': 'jes41947',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @prof_freedom: Stockholm Nightlife July 2021 - Still\n✅No lockdown\n✅No masks\n✅No business closures\n✅No school closures below grade 9\n✅No…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 5, 29, tzinfo=datetime.timezone.utc),
#   'retweets': 2103,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 249552678,
#   'username': 'technogaijin',
#   'author_description': 'Get your Pfizer vaccination. Continue wearing masks. Double mask indoors. The solution starts with you.',
#   'author_location': None,
#   'text': "@griffiths_rj @NotreRene @RCVogel2 @EmilyA_Cottrell @chrischirp If you get the POINT, you shouldn't be AT a party in the first place.  That attitude is the PROBLEM and part of the reason over 400k more people are dead in the US even after we got the vaccine and know masks work well to reduce COVID transmission.",
#   'created_at': datetime.datetime(2021, 12, 19, 21, 5, 20, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 1,
#   'quote_count': 0},
#  {'author_id': 824699774783811584,
#   'username': 'randee_euliss',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 5, 7, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 27246407,
#   'username': 'bowkie',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 5, 3, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 572282251,
#   'username': 'StoneColdPillar',
#   'author_description': 'Vote like your life depends on it. At the very least, the future of the planet does.🌎 Democracy. Equality. Human Rights. Election Integrity. Climate Change.',
#   'author_location': 'California, USA',
#   'text': '@DrTomFrieden It’s not okay to let COVID rage through kids unchecked.\n\nIt’s not okay to send kids to schools without 3 DOSES of vaccine for Omicron.\n\nIt’s not okay to send kids into schools without HEPA purifiers in every class, test-to-enter, and high qualified tested masks.\n\n@lapublichealth https://t.co/nzLNMwpBVp',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 4, 54, tzinfo=datetime.timezone.utc),
#   'retweets': 1,
#   'replies': 1,
#   'quote_count': 0},
#  {'author_id': 1432000693418737665,
#   'username': 'AGLeguiz',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 4, 36, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1520645012,
#   'username': 'CelticMoonlite',
#   'author_description': 'Functional Medicine ~ Environment ~ Wildlife Advocate who believes in personal choice and not the rigid narrative from our "gods of science"',
#   'author_location': 'California',
#   'text': "RT @DrEliDavid: We have vaccines, and we have vaccine-evading mutations. So what's the endgame for Covid? 🏁\n\nPerpetual lockdowns, travel ba…",
#   'created_at': datetime.datetime(2021, 12, 19, 21, 4, 24, tzinfo=datetime.timezone.utc),
#   'retweets': 601,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 2329290121,
#   'username': 'GaltWhoo',
#   'author_description': '#HamiltonRule Rule of law. Freedom. Vote integrity. Principles over party. Constitution.',
#   'author_location': None,
#   'text': 'RT @USBornNRaised: @ChrisCillizza Well, it’s been hard for me to watch you be lied to.\n\nFact:\n\n1. You don’t get a vaccine for a virus you a…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 3, tzinfo=datetime.timezone.utc),
#   'retweets': 44,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1240669780597714944,
#   'username': 'Tracey69327123',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 2, 53, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1311415537528983552,
#   'username': 'iQKENett',
#   'author_description': 'INFiSTED BY FING...\nINGENTING av det jag skriver är personligt eller ska tas personligt!',
#   'author_location': 'Kiruna',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 2, 3, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1411001518334095368,
#   'username': 'AnthonyJmercer',
#   'author_description': "follow up account. open up Now 🇬🇧🇬🇧🇬🇧🇬🇧No DMs unless it's mates.",
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 1, 20, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1431595534251397125,
#   'username': 'MI5_Spook',
#   'author_description': 'Why do the protected need to be protected from the unprotected by forcing the unprotected to use the protection that did not protect the protected in the first?',
#   'author_location': 'Somewhere on Earth',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 1, 20, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 757992450577276928,
#   'username': 'NYCOMECCorp',
#   'author_description': 'Promoting and supporting Osteopathic Graduate Medical Education since 1995',
#   'author_location': 'Old Westbury, NY',
#   'text': 'RT @DavidBroderDO: Move over Superman, COVID-19 ‘super immunity’ possible after breakthrough infections.\n\nThese patients have antibodies 1,…',
#   'created_at': datetime.datetime(2021, 12, 19, 21, 0, 30, tzinfo=datetime.timezone.utc),
#   'retweets': 1,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 427814660,
#   'username': 'MIKEYDBARNES1',
#   'author_description': 'Advocate Proportional Representation | Atheist | Teetotaler…',
#   'author_location': 'London, Ontario',
#   'text': "RT @DrEliDavid: We have vaccines, and we have vaccine-evading mutations. So what's the endgame for Covid? 🏁\n\nPerpetual lockdowns, travel ba…",
#   'created_at': datetime.datetime(2021, 12, 19, 21, 0, 22, tzinfo=datetime.timezone.utc),
#   'retweets': 601,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1330990382352633856,
#   'username': 'ThatJudexxx',
#   'author_description': 'Pro freedom of choice.',
#   'author_location': 'West Midlands, England',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 59, 48, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1036792414084714507,
#   'username': 'DavidBroderDO',
#   'author_description': 'Associate Dean, NYITCOM\nVice Speaker, American Osteopathic Association\n\n𝘓𝘢𝘶𝘨𝘩𝘵𝘦𝘳 𝘪𝘴 𝘵𝘩𝘦 𝘉𝘦𝘴𝘵 𝘔𝘦𝘥𝘪𝘤𝘪𝘯𝘦',
#   'author_location': 'Old Westbury, NY',
#   'text': 'Move over Superman, COVID-19 ‘super immunity’ possible after breakthrough infections.\n\nThese patients have antibodies 1,000% more effective than those generated after the 2nd Pfizer vaccine, says JAMA article.\n\nBut superheroes wear masks.\n\nhttps://t.co/yCh56Qog2s #COVID19 #Health',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 59, 13, tzinfo=datetime.timezone.utc),
#   'retweets': 1,
#   'replies': 1,
#   'quote_count': 0},
#  {'author_id': 245957521,
#   'username': 'KAYDM49',
#   'author_description': 'Dad to twins. 56th season @West Ham. Loved Upton Park hate London Arena. ST holder block 137 ⚒️ #England #WHU #BarmyArmyTraveller\n#EssexCCCMember #Bowie #Brexit',
#   'author_location': 'Brentwood, England.',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 58, 59, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1467997698020331521,
#   'username': 'Christi61144576',
#   'author_description': 'Chocolate and wine and gardening aficionado',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 57, 5, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 306680972,
#   'username': 'sidevans911',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 57, 2, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 57903099,
#   'username': 'Lebo_Snyman',
#   'author_description': '#BBG\n#Runner',
#   'author_location': 'South Africa',
#   'text': "RT @mjelse: @fearnley_k I have Long Covid, too, 12 months and 10 days. I do count them. The warning to everyone, from me, is: you don't wan…",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 56, 46, tzinfo=datetime.timezone.utc),
#   'retweets': 97,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 747878978866843648,
#   'username': 'david_david1968',
#   'author_description': '《英国观察》是陈昕舟和戴维共同发起创办的自媒体栏目，旨在以其多年的英国生活经历，展示英国社会的方方面面。 可加入本栏目电报群：https://t.co/0mi8voZSUT',
#   'author_location': 'London, England',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 56, 15, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 3706544956,
#   'username': 'AlexPecorabmw',
#   'author_description': 'Colombia mis raíces, Venezuela Mis bases, mi corazón;mi música, comida y tradiciones Y vivo En el país de la LIBERTAD USA De donde soy?',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 55, 21, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 254139236,
#   'username': 'PMugoMugo',
#   'author_description': 'Peace Researcher|| Journalist|| Author|| Agribusiness || Mostly; CVE, Media & Conflict, Electoral Violence, Humanitarian || F-1 fun. patrickmaragi@gmail.com',
#   'author_location': 'Nairobi, Kenya',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 54, 51, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1192423183422541825,
#   'username': 'PotheadDaVinci',
#   'author_description': 'opinionated and bold,\npoor listener, DMs for nudity only.\n\nRead these: https://t.co/xPHRheJUbb',
#   'author_location': None,
#   'text': "I'll be home for Christmas\nDrinking nog vaccine\nPlease stay at home\nAfraid and alone\nYou should be like me!\n\nCovid 19 won't find me, \nWearing masks I'll be,\nI'll be home for Christmas \nJust me and my vaccine\nI'll be home for Christmas \nJust me and my vaccine",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 53, 18, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1224143260073054210,
#   'username': 'YuriRiv02558750',
#   'author_description': 'Gods love',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 53, 9, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 888858657789624320,
#   'username': 'Brad59414697',
#   'author_description': 'Retired dad grandfather  husband left leaning traveller',
#   'author_location': 'Butterwick Nsw  Australia',
#   'text': 'How the hell are we going to get on top of covid without adequate vaccine supplies, face masks and QR codes?',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 52, 28, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 106452221,
#   'username': 'javierker',
#   'author_description': 'Cristiano Católico. Me gusta informar y estar informado. Peregrino por Vocación. Termine El Camino de Santiago (francés) el 21 de junio del 2014. Buen Camino!',
#   'author_location': 'Guadalajara, México',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 52, 18, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1472177863965253663,
#   'username': 'ElsaGrace16',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 51, 23, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 141003569,
#   'username': 'craigieboy007',
#   'author_description': 'RAF Vet. auto care, detailing and after market auto stylists. wraps, carbon fibre, body kits, sign writing, vehicle graphics, exterior/interior vehicle mods',
#   'author_location': 'Knottingley, West Yorkshire',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 50, 7, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1465056369317490699,
#   'username': 'TheAuthorsWord',
#   'author_description': 'Author of https://t.co/TjgYfaK4zW The Trilogy for 2022...\n#WestHam fan. My first match was at Upton Park in 1967 against Sunderland. Hurst scored a penalty...',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 49, 54, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1007602696793313280,
#   'username': 'CCCPBot1989',
#   'author_description': 'Friendly Russian bot from Russia! Здравствуйте!',
#   'author_location': 'From Russia!',
#   'text': '@jakedambergs @esaagar You are missing the salient point. Why is there not more money being allocated into home testing kits + added therapeutics to treat Covid on top of the vaccine? Yes, wear masks and get vaccinated. But why must that be the beginning and end of combating it?',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 49, 26, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1960400149,
#   'username': 'lorraineagate',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 48, 42, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 54222811,
#   'username': 'travi44',
#   'author_description': '',
#   'author_location': 'California, USA',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 48, 25, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 110213431,
#   'username': 'jorgeramosnews',
#   'author_description': 'Immigrant, journalist and anchor for Real America. \nInmigrante, periodista, conductor del Noticiero Univision y Al Punto.',
#   'author_location': 'América/America  ',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 48, 4, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1731805261,
#   'username': 'thrasherxy',
#   'author_description': 'Author, THE VIRAL UNDERCLASS | Celadon/Macmillan 2022 • Prof, Northwestern @MedillSchool @ISGMH • PhD in 🇺🇸 Studies • Repped by @McKinnonLit 📚',
#   'author_location': None,
#   'text': "@fred_guttenberg It is Dems who've\n\n—Ended testing sites in NY &amp; SF\n\n—SCOFFED at free home tests \n\n—FAILED to send out masks \n\n—FAILED to tie the infrastructure bill to BBB\n\n—Governed over more Covid deaths post-vaccine than Trump did mostly pre-vaccine?\n\nNot much attempting to govern IMO",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 47, 12, tzinfo=datetime.timezone.utc),
#   'retweets': 1,
#   'replies': 2,
#   'quote_count': 0},
#  {'author_id': 156712862,
#   'username': '1drm',
#   'author_description': 'Following life... one day at a time.',
#   'author_location': '🌴San Juan, Puerto Rico',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 46, 17, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1397092733681086467,
#   'username': 'kristidushku1',
#   'author_description': '🇦🇱🇧🇪',
#   'author_location': 'Bruxelles',
#   'text': "RT @DrEliDavid: We have vaccines, and we have vaccine-evading mutations. So what's the endgame for Covid? 🏁\n\nPerpetual lockdowns, travel ba…",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 46, 11, tzinfo=datetime.timezone.utc),
#   'retweets': 601,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1465099020762861579,
#   'username': 'VisicMiro',
#   'author_description': '',
#   'author_location': None,
#   'text': "@Gothamist Bill DeBlasio @NYCMayor doesn't want to admit that his Covid policies that relied on masks, Vaccine, Vaccine mandates and Vaccine Passports have FAILED.",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 45, 23, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 736612048390500352,
#   'username': 'SELAHinYorkPA',
#   'author_description': 'Army Vet,  Child of God, Healthcare activist, Voice of justice, rescue dog lover, single mom of 2 twenty somethings, Medicare Guru, orphan, pastor/educators kid',
#   'author_location': 'York, PA',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 44, 47, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1032222610518691840,
#   'username': 'IPricePsychAuth',
#   'author_description': 'business psychologist, author, conservative. Reform UK prospective Parliamentary candidate',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 44, 1, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1368049995534974976,
#   'username': 'Gary_no_numbers',
#   'author_description': '',
#   'author_location': None,
#   'text': "@berthyman @lsferguson Do Libertarians trust the FDA? I'm assuming you're against vaccine mandates which is good. Here's an article questioning the FDA's official stance on issuing Ivermectin to treat Covid 19.https://t.co/d87XtjaCmq",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 43, 22, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1169354135868755969,
#   'username': 'StephenPeo1',
#   'author_description': '',
#   'author_location': 'United Kingdom',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 42, 19, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1436764817474441220,
#   'username': 'Maddisodapop',
#   'author_description': '',
#   'author_location': None,
#   'text': '@lmUnFazed @Pianocrypto @mattbud @AnthonyB2367 @TrueLaurels He does, his twitter account is typical crypto anti-vaccine anti-mask rhetoric. I will say though if he considers masks to be miserable then he doesn’t really know what true misery is. Covid related or not.',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 41, 15, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 1,
#   'quote_count': 0},
#  {'author_id': 1515058170,
#   'username': 'SiljaCedeno',
#   'author_description': 'Lo que ves es lo que soy. ✌️😜',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 41, 14, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 20225520,
#   'username': 'Girlfridayadmi',
#   'author_description': 'Virtual Assistant based in Hampshire.',
#   'author_location': 'Havant, Hampshire',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 40, 36, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 274647959,
#   'username': 'alexpwong',
#   'author_description': 'Co-fundador @Audiomercados el primer servicio vía Audio de noticias financieras en español y tiempo real !!!! Prueba gratis 7 días',
#   'author_location': 'Spain ',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 40, 27, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1335894938689687552,
#   'username': 'life34855438',
#   'author_description': 'BREXIT ❤️I follow back #GBNews #antiwokeuk',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 40, 23, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1378829136349818880,
#   'username': 'SaraCarolineWa1',
#   'author_description': 'Anti vaccine passports and animal cruelty. Rescue animals make best pets. Love swearing.',
#   'author_location': 'United Kingdom',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 40, 13, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 497349753,
#   'username': 'ColettaFrank',
#   'author_description': 'Media Strategist/GR/PR/MC. Fmr @10NewsFirst @abcnews @AAPNewsWire journo. Roosters🐔Juve tragic. Everyone has a story to tell. Life’s too short for bad coffee.',
#   'author_location': 'Sydney (NSW), Gadigal Land',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 36, 56, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 759535635321401344,
#   'username': 'techy_tellechea',
#   'author_description': 'sitting by the side of the road watching this madness go by.',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 34, 53, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 306616453,
#   'username': 'Samoskal',
#   'author_description': 'Critical thinking with creative thinking, Ethics, health, social cohesion, M Ed(Ed Psych), B App Sc(Comp Sci), dynamic systems, S/w Proj Mgt, #renewablesage',
#   'author_location': 'Sydney',
#   'text': "Leaving pandemic mgt to 'personal responsibility' when there are crackpot antimask/antvaxxers in the community abusing ppl choosing to wear masks goes against all pandemic mgt principles. UK offers third dose vaccine after 3 mths, not Australia  #nswpol https://t.co/qErMlm5EsZ",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 34, 40, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 776279308041990144,
#   'username': 'pethamerica',
#   'author_description': '1st gen Chinese American. Pro-freedom, that’s why I chose America. Stupid ass baizuo should move to China if they love censorship so much.',
#   'author_location': 'Seattle a.k.a. Arkahm City, WA',
#   'text': '@MrDrewbles @DefiantLs What happened to treatment of Covid? Why act like the vaccine and masks (even the cloth masks) are the way out?',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 34, 31, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1341716547719598080,
#   'username': 'philip3dots',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 34, 13, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 608939278,
#   'username': 'mikebro30816865',
#   'author_description': 'Designer Loves NUFC,Cars,Bikes Brexit and Clarkson  Hates PC,Tree Huggers,the bloody EU,wind farms,Global warming stupidity,oh I could go on gab. as @MikeBrownn',
#   'author_location': 'morpeth / Girona',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 33, 11, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1137568723,
#   'username': 'MadisonKittay',
#   'author_description': '#BidenHarris #JoyfulWarrior #TeamPelosi #khive  Asian-American Democrat. Terrifying creature. She/her\n\nSnitch tag = Automatic Block',
#   'author_location': None,
#   'text': 'RT @GovKathyHochul: We\xa0know the vaccine and the boosters\xa0are highly effective in preventing hospitalizations caused by COVID.\xa0Get vaccinate…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 32, 5, tzinfo=datetime.timezone.utc),
#   'retweets': 171,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 301018979,
#   'username': '1967johnw',
#   'author_description': '',
#   'author_location': 'Leicester, England',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 30, 14, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 819403205486477314,
#   'username': 'tTerryy19',
#   'author_description': '',
#   'author_location': 'North Korea',
#   'text': '@dls1656 @mycathasaids @CassBasler I’m part of the problem😂 I’m vaccinated, I live my life without wondering anyone else’s vaccine status and don’t care about masks. Covid doesn’t pose a threat to me and with vaccines and life saving therapeutics I’m going to visit my family no matter what. You can isolate loser.',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 29, 11, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 969309576,
#   'username': 'Votto007',
#   'author_description': 'Turkmenistan state-affiliated media',
#   'author_location': None,
#   'text': 'more and more people are saying we fix covid for good in early 2022 with a vaccine mandate and no more testing or masks or any of that gay shit!!',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 26, 56, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 2,
#   'quote_count': 0},
#  {'author_id': 1087746309107474432,
#   'username': 'random2253',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 26, 11, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1923650185,
#   'username': 'geoffh25',
#   'author_description': 'Love marketing and MLM and helping others to enjoy the lifestyle this can bring. Leaves me free to live a relaxed time with family and friends.',
#   'author_location': 'Glasgow, UK',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 25, 7, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1472663426845528064,
#   'username': 'PazaakBot',
#   'author_description': 'Hello there',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 24, 42, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 4758165623,
#   'username': 'dormousegirl',
#   'author_description': 'She / her \nCafemocha in Animal Crossing Pocket Camp',
#   'author_location': None,
#   'text': 'RT @RGHIHygiene4All: Despite the new variant, the WHO continues to advise against travel restrictions, but warns that the (hygiene) measure…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 23, 6, tzinfo=datetime.timezone.utc),
#   'retweets': 309,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 28476297,
#   'username': 'Agouridis',
#   'author_description': 'Halloween Home Haunter! Don’t Punish Pain Advocate! Chronic Pain Warrior! advocate for chronic pain patients, cancer patients and veterans who suffer from pain!',
#   'author_location': 'Washington, DC',
#   'text': '@pj219 @GovLarryHogan Remove ALL masks mandates. Stop pushing for a vaccine that obviously is causing more harm then good. Stop the closures of in person for schools you know are coming. Enough of this covid scare tactics.',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 22, 14, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1389241081154449414,
#   'username': 'FilipAntoni3462',
#   'author_description': '⛳ 🚫No DMs',
#   'author_location': 'Dallas, TX',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 20, 58, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1396165255387025411,
#   'username': 'MiaWest2304',
#   'author_description': "Politically homeless politics geek! Life is for living. Like interesting discussion - we don't have to agree!",
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 20, 51, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 97802120,
#   'username': 'sydney_zakiya',
#   'author_description': 'Artist & Designer. RTing randomness, Bravo Housewives & anything Dallas Cowboys or Beyoncé related. Extroverted Loner 😎',
#   'author_location': 'somewhere covered in glitter ',
#   'text': "RT @mjelse: @fearnley_k I have Long Covid, too, 12 months and 10 days. I do count them. The warning to everyone, from me, is: you don't wan…",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 19, 18, tzinfo=datetime.timezone.utc),
#   'retweets': 97,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 2260248067,
#   'username': 'Taylod61',
#   'author_description': '❌ Believer in England. Golf nut, Supporter of AMW & For Britain. Like things right and support GBNews. I block rainbows, knee takers and woke.',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 19, 4, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 2281633597,
#   'username': 'Kenwxman',
#   'author_description': 'Now retired expert meteorologist with AccuWeather from 1974-2018. Proud Penn State grad, weather enthusiast, and poker player.',
#   'author_location': None,
#   'text': '@notarunnerkopp @BigJoeBastardi You are right, there are more tests in CA. But I believe that’s all part of a better plan to control Covid. More tests = earlier finding of Covid and getting that person to isolate. Masks work and of course the vaccine is doing wonders keeping people out off the hospital/morgue.',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 18, 53, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 954601925072207877,
#   'username': 'AdrianH02822550',
#   'author_description': 'Writer, archivist',
#   'author_location': 'Wanganui District, New Zealand',
#   'text': "@spectator The Covid 19 virus is libertarian so it's a good virus and masks and vaccine passports are an infringement of its liberties? This is lunacy, is it not?",
#   'created_at': datetime.datetime(2021, 12, 19, 20, 18, 29, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1448516235755286532,
#   'username': 'Dreamsdesignbik',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 17, 55, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1466573250125864969,
#   'username': 'T18114787',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 17, 2, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1094964446391353344,
#   'username': 'Lillywhite111',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 16, 48, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 17271903,
#   'username': 'BethRenee',
#   'author_description': 'supporting advocates and action for a more humane world #climate #women #sustainability #democracy',
#   'author_location': 'Minnesota and France',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 15, 37, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1379370333904453632,
#   'username': 'WTF20218',
#   'author_description': "Twitter doesn't like what I have to say. I’m back with 2.0. we must fight for #America. @Armageddon_2021 on @GETTR",
#   'author_location': 'What used to be #America',
#   'text': '@logosaetos @charliekirk11 I’m an RN, who’s vaccinated for everything except the shot with no long-term data behind it. I didn’t have to get the flu vaccine because we already have to wear masks, which is what the exemption required. I’ve never had Covid, and protect my patients very well also. 1/2',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 15, 8, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 1,
#   'quote_count': 0},
#  {'author_id': 975540274003959810,
#   'username': 'booksandmycat',
#   'author_description': 'Book nerd 📚, geekery, humanist, exvangelical, ailurophile 🐱, she/her',
#   'author_location': 'Minneapolis, MN',
#   'text': 'RT @nytimes: “This virus is extraordinary,” Dr. Anthony Fauci said on Sunday in reference to the Omicron variant. As Americans wrestle with…',
#   'created_at': datetime.datetime(2021, 12, 19, 20, 14, 53, tzinfo=datetime.timezone.utc),
#   'retweets': 94,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 2294193683,
#   'username': 'GovKhan',
#   'author_description': 'Catholic, living with autism, fitness buff, and fan of the National Football League',
#   'author_location': 'Newark, NJ',
# ...
#   'username': 'michellewrossi',
#   'author_description': 'British born with Italian roots. Interested in democracy, justice, free will and living our best lives.',
#   'author_location': 'West Sussex',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 11, 4, 11, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1143475468051652608,
#   'username': 'john_ishappy',
#   'author_description': '',
#   'author_location': 'London, England',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 11, 3, 26, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 3324647007,
#   'username': 'jameskilgallon8',
#   'author_description': "you reap what you sow....don't be a twat... Scottish..COYBIG..CELTIC",
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 11, 2, 38, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 333074358,
#   'username': 'KevinAtp',
#   'author_description': 'Small biz owner, Ex-Mil, Prof-landlord, Heli-Pilot, Investor, Loves dogs. Represents the smallest minority class which is always forgotten... the individual!',
#   'author_location': 'London',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 11, 2, 26, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 62377119,
#   'username': 'Scotwesterman',
#   'author_description': 'Im a dad, husband and a part time wedding photographer.',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 11, 1, 9, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 78951169,
#   'username': 'nZeesh',
#   'author_description': 'A doctor, husband, son, brother and a member of MKA. Love 4 all, Hatred 4 none!',
#   'author_location': 'Pakistan',
#   'text': 'RT @FaheemYounus: Driving has risks. Yet we don’t wait for zero accidents. We learn/embrace the safety steps and keep driving\n\nCOVID has ri…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 59, 57, tzinfo=datetime.timezone.utc),
#   'retweets': 704,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 719637459794051073,
#   'username': 'Sozzinski',
#   'author_description': 'I used to be of the Left, until they abandoned reason, showed signs of serious mental illness, and became far, far more dangerous than the Right.',
#   'author_location': 'Central London, UK',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 59, 55, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1098091132087660544,
#   'username': 'smokedsomething',
#   'author_description': 'No, I am not a Biohazard after smoking it.',
#   'author_location': 'Colorado',
#   'text': '@dreamondreamer9 @SylvesterTurner Sadly my buddy of mine was obese and had the covid. He died unfortunately. He wore masks as well and still got it. This was before the vaccine came out.',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 59, 38, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1394271771508019201,
#   'username': 'afcaziva',
#   'author_description': 'PVV vanaf het eerste uur! \nRottweilers Ajax\nTrump MAGA2024\nNexit',
#   'author_location': None,
#   'text': "RT @DrEliDavid: We have vaccines, and we have vaccine-evading mutations. So what's the endgame for Covid? 🏁\n\nPerpetual lockdowns, travel ba…",
#   'created_at': datetime.datetime(2021, 12, 19, 10, 59, 28, tzinfo=datetime.timezone.utc),
#   'retweets': 601,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1135849602312232962,
#   'username': 'Russell75188603',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 59, 26, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 721025394430881793,
#   'username': 'cjcgekko',
#   'author_description': 'Greed is good',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 59, 9, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1335968924651966467,
#   'username': 'AnneWatkis',
#   'author_description': 'Granny, mother, history buff',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 58, 47, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 2321279598,
#   'username': 'ik15081958',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 58, 39, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 4195512575,
#   'username': 'alan_lingwood',
#   'author_description': 'Former Royal Marine - Passionate about my Country and I am a Staunch Brexiteer. Recently retired, I now devote my time to travelling, my family and politics.',
#   'author_location': 'United Kingdom',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 58, 21, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 54130269,
#   'username': 'PhilCourchesne',
#   'author_description': '',
#   'author_location': 'Montreal, Qc',
#   'text': "@LP_LaPresse We have vaccines, and we have vaccine-evading mutations. So what's the endgame for Covid? 🏁\n\nPerpetual lockdowns, travel bans, masks, and boosters?\n\nThe pandemic phase is over for many months now. No excess mortality. We should stop counting cases and lift all restrictions.",
#   'created_at': datetime.datetime(2021, 12, 19, 10, 58, 10, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 347960464,
#   'username': 'regtwn74',
#   'author_description': 'nobody needs to know',
#   'author_location': None,
#   'text': 'RT @patriottakes: Kari Lake supporter Ethan Schmidt harassing people at Walgreens getting the covid vaccine. His shirt says, “masks are gay…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 57, 41, tzinfo=datetime.timezone.utc),
#   'retweets': 368,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1089761967378706432,
#   'username': 'Joannaregis3',
#   'author_description': 'Original account nuked for truth telling, Against all Government mandates & Convid rubbish',
#   'author_location': 'Glasgow',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 57, 32, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1308456603704844292,
#   'username': 'ForceXrp',
#   'author_description': 'winner',
#   'author_location': 'Great Britain ',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 55, 59, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1226600655357345792,
#   'username': 'ann_neels',
#   'author_description': 'Mother of 2 boys.  Grandmother of 4.  Married to my best friend\n\nhttps://t.co/hbrDPFJoFf…\n\nhttps://t.co/ASs9wzt5V1',
#   'author_location': None,
#   'text': 'RT @patriottakes: Kari Lake supporter Ethan Schmidt harassing people at Walgreens getting the covid vaccine. His shirt says, “masks are gay…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 55, 54, tzinfo=datetime.timezone.utc),
#   'retweets': 368,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1356369539936657408,
#   'username': 'SeanGal47953425',
#   'author_description': '',
#   'author_location': None,
#   'text': "RT @DrEliDavid: We have vaccines, and we have vaccine-evading mutations. So what's the endgame for Covid? 🏁\n\nPerpetual lockdowns, travel ba…",
#   'created_at': datetime.datetime(2021, 12, 19, 10, 55, 36, tzinfo=datetime.timezone.utc),
#   'retweets': 601,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 3122785923,
#   'username': 'EvKazoo',
#   'author_description': 'Views are mine, or perhaps more so of those who inspired me, Plato and Leonidas.\nThe world needs much more of both today.',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 54, 33, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 4864592693,
#   'username': 'KJankowskiUK',
#   'author_description': 'Sherlocks are so funny',
#   'author_location': 'Gainsborough, England',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 54, 22, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1370353626330370053,
#   'username': 'mariere23775093',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 53, 53, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 547155645,
#   'username': 'lollychap',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 53, 46, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1348241333438345217,
#   'username': 'Rosemar45170256',
#   'author_description': 'I am believe in truth and Justice.\nI am British and proud. I also believe in peace.🇬🇧🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🙏❤',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 53, 33, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 256661626,
#   'username': 'LJayneCameron',
#   'author_description': 'Proud mum of Emily and Mary',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 52, 40, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1261631675836096513,
#   'username': 'NathanB88437861',
#   'author_description': '',
#   'author_location': None,
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 51, 47, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1298627754011824130,
#   'username': 'RodgersRobotics',
#   'author_description': 'CPS/CTU Pre-Engineering & Computer Science Teacher. Personal account; views my own.\nhttps://t.co/2Q9GLUgKm1',
#   'author_location': 'South Shore, Chicago, IL',
#   'text': 'We all need free N95 masks and free rapid Covid tests and a vaccine mandate for public health.',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 51, 31, tzinfo=datetime.timezone.utc),
#   'retweets': 0,
#   'replies': 1,
#   'quote_count': 0},
#  {'author_id': 3651551963,
#   'username': 'JedMcJedi',
#   'author_description': 'Direct witness close encounter 1st kind (50m)..... 1998',
#   'author_location': 'UK',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 50, 36, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 19149911,
#   'username': 'Latics',
#   'author_description': '',
#   'author_location': 'England',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 48, 44, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 19559054,
#   'username': 'lisajlb1970',
#   'author_description': 'Head of e-commerce. 💻 \nLove: \nTravelling ✈ yeah right not anymore!\nLive music 🎸 well I did!\nEating out 🥘 ? for how long? \nNB Dreamcatcha 🛥\nThe Gym 🤸\u200d♀️',
#   'author_location': 'Manchester, England',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 48, 23, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 1168117136855879683,
#   'username': 'Godfrey28482926',
#   'author_description': "Proud 'Boomer' -  We created the modern, civilised, prosperous, secular, technological world.",
#   'author_location': 'South East England.  ',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 48, 15, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  {'author_id': 295192974,
#   'username': 'janatfootie',
#   'author_description': '',
#   'author_location': 'Hornchurch',
#   'text': 'RT @talkRADIO: "We don\'t need vaccine passports. There is no evidence they work. We don\'t need masks for the same reason. We don\'t need to…',
#   'created_at': datetime.datetime(2021, 12, 19, 10, 48, 8, tzinfo=datetime.timezone.utc),
#   'retweets': 449,
#   'replies': 0,
#   'quote_count': 0},
#  ...]

# %%
df
# Out:
#                  author_id         username  \
# 0               1053785240       shimtunley
# 1                103509670        indiraeng
# 2       984452302579912704        harte_the
# 3      1459285370835771403    Paulina100722
# 4       944865799369515008  JustinM79380965
# ...                    ...              ...
# 11669  1254835769316904961     corona_tweet
# 11670   757648131051786241        Brent_C81
# 11671           3247497857      sagittar744
# 11672           1636224168      saurabh_iam
# 11673             40958756       allegro572
#
#                                       author_description  \
# 0
# 1
# 2                         Just a Freedom Loving American
# 3      President DJT🇺🇸👍🏼❤️ #MAGA #KAG #LEADRIGHT   #S...
# 4
# ...                                                  ...
# 11669
# 11670  Just a average joe from south Louisiana taking...
# 11671  .. dalle orrende profondità un sussulto che sc...
# 11672            हिन्दी हैं हम, वतन है हिन्दोस्तां हमारा
# 11673  pianist teacher composer wife♡ mother♡ love ne...
#
#             author_location  \
# 0                      None
# 1                      None
# 2             United States
# 3                Maine, USA
# 4      out there, somewhere
# ...                     ...
# 11669                  None
# 11670        Louisiana, USA
# 11671             Lombardia
# 11672      Hyderabad, India
# 11673                kansas
#
#                                                     text  \
# 0      RT @RGHIHygiene4All: Despite the new variant, ...
# 1      RT @nytimes: “This virus is extraordinary,” Dr...
# 2      @mohr_glen @Jenifer20238204 @impjr @dbongino S...
# 3      RT @CJ_J777: @OregonGovBrown If a vaccinated p...
# 4      RT @talkRADIO: "We don't need vaccine passport...
# ...                                                  ...
# 11669  RT @Jerusalem_Post: Experts agree that now is ...
# 11670  RT @ianmSC: Europe’s masks and vaccine passpor...
# 11671  RT @steve_hanke: #EconWatch: With more than 56...
# 11672  RT @Jerusalem_Post: Experts agree that now is ...
# 11673  RT @Jerusalem_Post: Experts agree that now is ...
#
#                      created_at  retweets  replies  quote_count
# 0     2021-12-19 21:19:15+00:00       309        0            0
# 1     2021-12-19 21:18:22+00:00        94        0            0
# 2     2021-12-19 21:17:02+00:00         0        0            0
# 3     2021-12-19 21:16:19+00:00         4        0            0
# 4     2021-12-19 21:16:19+00:00       449        0            0
# ...                         ...       ...      ...          ...
# 11669 2021-12-12 21:23:57+00:00         4        0            0
# 11670 2021-12-12 21:23:57+00:00       144        0            0
# 11671 2021-12-12 21:23:50+00:00        15        0            0
# 11672 2021-12-12 21:23:40+00:00         4        0            0
# 11673 2021-12-12 21:23:10+00:00         4        0            0
#
# [11674 rows x 9 columns]
